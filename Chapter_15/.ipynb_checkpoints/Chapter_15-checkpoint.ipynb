# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10)) # wave 1
#     print(series.shape)
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) # noise
#     print(series[..., np.newaxis].shape)
    return series[..., np.newaxis].astype(np.float32)

# %%
batch_size = 3
n_steps = 50
series = generate_time_series(batch_size, n_steps)
# (3, 50)
# (3, 50, 1)

# %%
fig, axs = plt.subplots(1,batch_size, figsize=(12,6))
for plot_index in range(0,batch_size):
    axs[plot_index].plot(range(0,n_steps), series[plot_index, ...], '-o')
    axs[plot_index].set_aspect('auto')

# %% [markdown]
# Create training, validation, and testing data.

# %%
n_steps = 50
series = generate_time_series(10000, n_steps+1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (7000, 50, 1)
# (7000, 1)

# %%
np.array([[[0]]]).shape
# Out:
# (1, 1, 1)

# %%
series[:7000, -1].shape
# Out:
# (7000, 1)

# %% [markdown]
# Baseline metrics

# %% [markdown]
# 1. Repeat the most recent value from the time series, as the prediction

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.02067841

# %% [markdown]
# 2. Linear regression on all the elements of the time series

# %%
# %%time
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape = [n_steps, 1]),
    keras.layers.Dense(1)
])

model.compile(loss='mse', optimizer='adam')
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 2s 219us/sample - loss: 0.1021 - val_loss: 0.0556
# Epoch 2/20
# 7000/7000 [==============================] - 1s 91us/sample - loss: 0.0395 - val_loss: 0.0281
# Epoch 3/20
# 7000/7000 [==============================] - 1s 89us/sample - loss: 0.0213 - val_loss: 0.0163
# Epoch 4/20
# 7000/7000 [==============================] - 1s 88us/sample - loss: 0.0139 - val_loss: 0.0116
# Epoch 5/20
# 7000/7000 [==============================] - 1s 88us/sample - loss: 0.0108 - val_loss: 0.0094
# Epoch 6/20
# 7000/7000 [==============================] - 1s 85us/sample - loss: 0.0093 - val_loss: 0.0082
# Epoch 7/20
# 7000/7000 [==============================] - 1s 88us/sample - loss: 0.0083 - val_loss: 0.0074
# Epoch 8/20
# 7000/7000 [==============================] - 1s 88us/sample - loss: 0.0075 - val_loss: 0.0066
# Epoch 9/20
# ...

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/1 [==============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %% [markdown]
# Implementing a simple RNN

# %%
# %%time
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None, 1])
])

optimizer = keras.optimizers.Adam(lr=0.005)
model.compile(loss='mse', optimizer=optimizer)
history = model.fit(X_train, y_train, epochs = 20, 
                    validation_data=(X_valid, y_valid))
# Wall time: 2min 45s at home
# Out:
# Train on 7000 samples, validate on 2000 samples
# Epoch 1/20
# 7000/7000 [==============================] - 10s 1ms/sample - loss: 0.0953 - val_loss: 0.0485
# Epoch 2/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0364 - val_loss: 0.0295
# Epoch 3/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0247 - val_loss: 0.0218
# Epoch 4/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0193 - val_loss: 0.0176
# Epoch 5/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0162 - val_loss: 0.0150
# Epoch 6/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0142 - val_loss: 0.0133
# Epoch 7/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0129 - val_loss: 0.0122
# Epoch 8/20
# 7000/7000 [==============================] - 8s 1ms/sample - loss: 0.0121 - val_loss: 0.0115
# Epoch 9/20
# ...

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 2000/1 [==============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
